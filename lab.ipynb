# %% [markdown]
# ## Use this notebook to test and lab with the code base

# %% [markdown]
# ### Visualize a random image

# %%
from visualizers import visualize_random_image

# Visualization
visualize_random_image()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ### Predict a random image

# %%
from prediction import predict_random_image

predict_random_image(
    model_path="./models/model_2022-04-15 11 34 02.128306.pth", num_preds=1
)
# Out:
# Prediction labels: [1]
